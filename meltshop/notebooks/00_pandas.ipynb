# %%
import pandas as pd
import numpy as np

# %%
raw = pd.read_excel("../data/eaf.xlsx")
raw.head()
# Out:
#            start_date           stop_date   heat_id steel_grade  num_buckets  \
# 0 2023-01-09 09:44:10 2023-01-09 10:42:42  35019988    SAE 1011            3
# 1 2023-01-09 10:42:48 2023-01-09 11:48:42  35019989    SAE 1011            2
# 2 2023-01-09 11:48:46 2023-01-09 12:58:08  35019990    SAE 1011            2
# 3 2023-01-09 12:58:14 2023-01-09 13:55:24  35019991    SAE 1011            2
# 4 2023-01-09 13:55:28 2023-01-09 14:46:10  35019992    SAE 1011            2
#
#    total_scrap_t  bucket1_t  bucket2_t  bucket3_t  coque_kg  ...  \
# 0         95.200     43.000     32.000       20.2       150  ...
# 1         77.823     42.684     35.139        0.0       150  ...
# 2         81.024     45.486     35.538        0.0       150  ...
# 3         69.922     43.383     26.539        0.0       150  ...
# 4         80.993     45.393     35.600        0.0         0  ...
#
#    ladle_N2_stirr_Nm3  tap_lime_kg tap_dolo_kg tap_CaF2_kg tap_Al_kg  \
# ...

# %%
raw.columns
# Out:
# Index(['start_date', 'stop_date', 'heat_id', 'steel_grade', 'num_buckets',
#        'total_scrap_t', 'bucket1_t', 'bucket2_t', 'bucket3_t', 'coque_kg',
#        'lime_kg', 'dolo_kg', 'duration', 'p_on', 'p_off', 'avg_power_MW',
#        'energy_MWh', 'energy_melt1_MWh', 'energy_melt2_MWh',
#        'energy_melt3_MWh', 'energy_refining_MWh', 'oxygen_module_Nm3',
#        'oxygen_total_Nm3', 'carbon_module_kg', 'fuel_module_Nm3',
#        'fuel_total_Nm3', 'spec_energy_MWh/t', 'spec_oxygen_module_Nm3/t',
#        'spec_carbon_module_kg/t', 'spec_fuel_Nm3/t', 'spec_coque_kg/t',
#        'spec_lime_dolo_kg_t', 'final_temp_deg', 'final_oxygen_ppm',
#        'end_hot_heel_t', 'tapped_weight_t', 'tapped_steel_t', 'tap_duration',
#        'yield_%', 'ladle_Ar_stirr_Nm3', 'ladle_N2_stirr_Nm3', 'tap_lime_kg',
#        'tap_dolo_kg', 'tap_CaF2_kg', 'tap_Al_kg', 'tap_FeSi_kg',
#        'tap_FeSiMn_kg', 'tap_FeMn_kg', 'tap_SiC_kg', 'tap_carbon_kg'],
#       dtype='str')

# %%
raw.index
# Out:
# RangeIndex(start=0, stop=9937, step=1)
